# %%
import numpy as np
import deepcell_tracking.utils as tracking
from deepcell_tracking.utils import Track
from pathlib import Path

file_name = Path("/data/3T3_HeLa_HEK_RAW_V2.trks")
cell_tracks = Track(file_name)

feature_dict = cell_tracks._get_features()
num_batches = feature_dict['centroids'].shape[0]

possibly_died = {}
#batch numbers are numbered as per their indices
for batch in range(num_batches):
    last_frame = 0
    #frames are numbered as per their indices
    for frame in range(feature_dict['centroids'].shape[1] - 1, -1, -1):
        if not np.array_equal(feature_dict['centroids'][batch][frame], np.zeros((39, 2))):
            last_frame = frame
            break    
    possibly_died_batch = {}
    for cell_num in cell_tracks.lineages[batch]:
        cell_lineage = cell_tracks.lineages[batch].get(cell_num)
        if not cell_lineage.get('daughters') and cell_lineage.get('frames')[-1] != last_frame:
            possibly_died_batch[cell_num] = cell_lineage.get('frames')[-1]
    possibly_died[batch] = possibly_died_batch

# %%
max_batch_deaths = 0
for batch in possibly_died:
    max_deaths = len(possibly_died.get(batch))
    if max_deaths > max_batch_deaths:
        max_batch_deaths = max_deaths

fig, ax = plt.subplots(num_batches, max_batch_deaths, figsize=(10, 7))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-0d8abef1cabb> in <module>
#       5         max_batch_deaths = max_deaths
#       6
# ----> 7 fig, ax = plt.subplots(num_batches, max_batch_deaths, figsize=(10, 7))
#
# NameError: name 'plt' is not defined

# %%
import matplotlib.pyplot as plt

max_batch_deaths = 0
for batch in possibly_died:
    max_deaths = len(possibly_died.get(batch))
    if max_deaths > max_batch_deaths:
        max_batch_deaths = max_deaths

fig, ax = plt.subplots(num_batches, max_batch_deaths, figsize=(10, 7))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-6829964fb26f> in <module>
#       7         max_batch_deaths = max_deaths
#       8
# ----> 9 fig, ax = plt.subplots(num_batches, max_batch_deaths, figsize=(10, 7))
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/cbook/deprecation.py in wrapper(*args, **kwargs)
#     449                 "parameter will become keyword-only %(removal)s.",
#     450                 name=name, obj_type=f"parameter of {func.__name__}()")
# --> 451         return func(*args, **kwargs)
#     452
#     453     return wrapper
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/pyplot.py in subplots(nrows, ncols, sharex, sharey, squeeze, subplot_kw, gridspec_kw, **fig_kw)
#    1288     axs = fig.subplots(nrows=nrows, ncols=ncols, sharex=sharex, sharey=sharey,
#    1289                        squeeze=squeeze, subplot_kw=subplot_kw,
# ...

# %%
import matplotlib.pyplot as plt

# %%
max_batch_deaths = 0
for batch in possibly_died:
    max_deaths = len(possibly_died.get(batch))
    if max_deaths > max_batch_deaths:
        max_batch_deaths = max_deaths

# %%
max_batch_deaths
# Out:
# 9

# %%
fig, ax = plt.subplots(num_batches, max_batch_deaths, figsize=(10, 7))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-7b736a6f177b> in <module>
# ----> 1 fig, ax = plt.subplots(num_batches, max_batch_deaths, figsize=(10, 7))
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/cbook/deprecation.py in wrapper(*args, **kwargs)
#     449                 "parameter will become keyword-only %(removal)s.",
#     450                 name=name, obj_type=f"parameter of {func.__name__}()")
# --> 451         return func(*args, **kwargs)
#     452
#     453     return wrapper
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/pyplot.py in subplots(nrows, ncols, sharex, sharey, squeeze, subplot_kw, gridspec_kw, **fig_kw)
#    1288     axs = fig.subplots(nrows=nrows, ncols=ncols, sharex=sharex, sharey=sharey,
#    1289                        squeeze=squeeze, subplot_kw=subplot_kw,
# -> 1290                        gridspec_kw=gridspec_kw)
# ...

# %%
fig, ax = plt.subplots(2, 2, figsize=(10, 7))

# %%
ax[0][0]
# Out:
# <AxesSubplot:>

# %%
ax[1][1]
# Out:
# <AxesSubplot:>

# %%
ax[1][2]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-11-34d12bef1804> in <module>
# ----> 1 ax[1][2]
#
# IndexError: index 2 is out of bounds for axis 0 with size 2

# %%
fig, ax = plt.subplots(2, 10, figsize=(10, 7))

# %%
fig, ax = plt.subplots(600, 10, figsize=(10, 7))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-6c72823178ef> in <module>
# ----> 1 fig, ax = plt.subplots(600, 10, figsize=(10, 7))
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/cbook/deprecation.py in wrapper(*args, **kwargs)
#     449                 "parameter will become keyword-only %(removal)s.",
#     450                 name=name, obj_type=f"parameter of {func.__name__}()")
# --> 451         return func(*args, **kwargs)
#     452
#     453     return wrapper
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/pyplot.py in subplots(nrows, ncols, sharex, sharey, squeeze, subplot_kw, gridspec_kw, **fig_kw)
#    1288     axs = fig.subplots(nrows=nrows, ncols=ncols, sharex=sharex, sharey=sharey,
#    1289                        squeeze=squeeze, subplot_kw=subplot_kw,
# -> 1290                        gridspec_kw=gridspec_kw)
# ...

# %%
fig, ax = plt.subplots(100, 10, figsize=(10, 7))

# %%
from skimage.io import imsave
imsave('/home/mkant/big_image_test')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-8d0ca41dadc1> in <module>
#       1 from skimage.io import imsave
# ----> 2 imsave('/home/mkant/big_image_test')
#
# TypeError: imsave() missing 1 required positional argument: 'arr'

# %%
from skimage.io import imsave
imsave('/home/mkant/big_image_test', ws.astype(np.uint16))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-427117c8e248> in <module>
#       1 from skimage.io import imsave
# ----> 2 imsave('/home/mkant/big_image_test', ws.astype(np.uint16))
#
# NameError: name 'ws' is not defined

# %%
plt.savefig('/home/mkant/big_image_test')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-17-170ba091a1e6> in <module>
# ----> 1 plt.savefig('/home/mkant/big_image_test')
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/pyplot.py in savefig(*args, **kwargs)
#     857 def savefig(*args, **kwargs):
#     858     fig = gcf()
# --> 859     res = fig.savefig(*args, **kwargs)
#     860     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     861     return res
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/figure.py in savefig(self, fname, transparent, **kwargs)
#    2309                 patch.set_edgecolor('none')
#    2310
# -> 2311         self.canvas.print_figure(fname, **kwargs)
#    2312
#    2313         if transparent:
#
# ...

# %%
plt.savefig('/home/mkant/big_image_test.png')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-18-ae38be4903c7> in <module>
# ----> 1 plt.savefig('/home/mkant/big_image_test.png')
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/pyplot.py in savefig(*args, **kwargs)
#     857 def savefig(*args, **kwargs):
#     858     fig = gcf()
# --> 859     res = fig.savefig(*args, **kwargs)
#     860     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     861     return res
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/figure.py in savefig(self, fname, transparent, **kwargs)
#    2309                 patch.set_edgecolor('none')
#    2310
# -> 2311         self.canvas.print_figure(fname, **kwargs)
#    2312
#    2313         if transparent:
#
# ...

# %%
fig.savefig('/home/mkant/big_image_test.png')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-19-65837e3a7586> in <module>
# ----> 1 fig.savefig('/home/mkant/big_image_test.png')
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/figure.py in savefig(self, fname, transparent, **kwargs)
#    2309                 patch.set_edgecolor('none')
#    2310
# -> 2311         self.canvas.print_figure(fname, **kwargs)
#    2312
#    2313         if transparent:
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2215                     orientation=orientation,
#    2216                     bbox_inches_restore=_bbox_inches_restore,
# -> 2217                     **kwargs)
#    2218             finally:
# ...

# %%
fig.savefig('big_image_test.png')

# %%
fig, ax = plt.subplots(2, 2)

# %%
fig, ax = plt.subplots(2, 9)

# %%
fig, ax = plt.subplots(2, 9, figsize=(20, 14))

# %%
fig, ax = plt.subplots(2, 9, figsize=(20, 10))

# %%
fig, ax = plt.subplots(2, 9, figsize=(30, 10))

# %%
fig, ax = plt.subplots(100, 9, figsize=(30, 500))

# %%
fig.savefig('../big_image_test_1.png')

# %%
fig.savefig('big_image_test_1.png')

# %%
fig.savefig('big_image_test_1.pdf')

# %%
ax[0][0]
# Out:
# <AxesSubplot:>

# %%
fig, ax = plt.subplots(num_batches, max_batch_deaths, figsize=(10, 7))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/lib/python3.6/inspect.py in _bind(self, args, kwargs, partial)
#    2958             try:
# -> 2959                 arg_val = kwargs.pop(param_name)
#    2960             except KeyError:
#
# KeyError: 'forbidden'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-32-7b736a6f177b> in <module>
# ----> 1 fig, ax = plt.subplots(num_batches, max_batch_deaths, figsize=(10, 7))
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/cbook/deprecation.py in wrapper(*args, **kwargs)
#     449                 "parameter will become keyword-only %(removal)s.",
#     450                 name=name, obj_type=f"parameter of {func.__name__}()")
# --> 451         return func(*args, **kwargs)
#     452
# ...

# %%
fig, ax = plt.subplots(num_batches, max_batch_deaths, figsize=(30 * max_batch_deaths / 9, 10 * num_batches / 2))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# /usr/local/lib/python3.6/dist-packages/IPython/core/pylabtools.py in <lambda>(fig)
#     246
#     247     if 'png' in formats:
# --> 248         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     249     if 'retina' in formats or 'png2x' in formats:
#     250         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# /usr/local/lib/python3.6/dist-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
# ...

# %%
for batch in range(num_batches):
    possibly_died_batch = possibly_died.get(batch).keys()
    pos = 0
    for cell in possibly_died_batch:
        ax[batch][pos].imshow(feature_dict['appearances'][batch][possibly_died.get(batch).get(cell)])
        ax[batch][pos].set_title('Batch {}, Cell {}'.format(batch, cell))
        pos += 1
        
fig.savefig('possibly_died_appearances')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-34-0838c10fedad> in <module>
#       3     pos = 0
#       4     for cell in possibly_died_batch:
# ----> 5         ax[batch][pos].imshow(feature_dict['appearances'][batch][possibly_died.get(batch).get(cell)])
#       6         ax[batch][pos].set_title('Batch {}, Cell {}'.format(batch, cell))
#       7         pos += 1
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1445     def inner(ax, *args, data=None, **kwargs):
#    1446         if data is None:
# -> 1447             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1448
#    1449         bound = new_sig.bind(ax, *args, **kwargs)
#
# ...

# %%
for batch in range(num_batches):
    fig, ax = plt.subplots(1, max_batch_deaths, figsize=(30 * max_batch_deaths / 9, 10))
    possibly_died_batch = possibly_died.get(batch).keys()
    pos = 0
    for cell in possibly_died_batch:
        ax[pos].imshow(feature_dict['appearances'][batch][possibly_died.get(batch).get(cell)])
        ax[pos].set_title('Batch {}, Cell {}'.format(batch, cell))
        plt.show
        pos += 1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-35-e14d8c87e4b0> in <module>
#       4     pos = 0
#       5     for cell in possibly_died_batch:
# ----> 6         ax[pos].imshow(feature_dict['appearances'][batch][possibly_died.get(batch).get(cell)])
#       7         ax[pos].set_title('Batch {}, Cell {}'.format(batch, cell))
#       8         plt.show
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1445     def inner(ax, *args, data=None, **kwargs):
#    1446         if data is None:
# -> 1447             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1448
#    1449         bound = new_sig.bind(ax, *args, **kwargs)
#
# ...

# %%
for batch in range(num_batches):
    fig, ax = plt.subplots(1, max_batch_deaths, figsize=(30 * max_batch_deaths / 9, 10))
    possibly_died_batch = possibly_died.get(batch).keys()
    pos = 0
    for cell in possibly_died_batch:
        ax[pos].imshow(feature_dict.get('appearances')[batch][possibly_died.get(batch).get(cell)][cell])
        ax[pos].set_title('Batch {}, Cell {}'.format(batch, cell))
        plt.show
        pos += 1
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-36-00fc703355a3> in <module>
#       1 for batch in range(num_batches):
# ----> 2     fig, ax = plt.subplots(1, max_batch_deaths, figsize=(30 * max_batch_deaths / 9, 10))
#       3     possibly_died_batch = possibly_died.get(batch).keys()
#       4     pos = 0
#       5     for cell in possibly_died_batch:
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/cbook/deprecation.py in wrapper(*args, **kwargs)
#     449                 "parameter will become keyword-only %(removal)s.",
# ...

# %%
for batch in range(num_batches):
    fig, ax = plt.subplots(1, max_batch_deaths, figsize=(30 * max_batch_deaths / 9, 10))
    possibly_died_batch = possibly_died.get(batch).keys()
    pos = 0
    for cell in possibly_died_batch:
        ax[pos].imshow(feature_dict.get('appearances')[batch][possibly_died.get(batch).get(cell)][cell])
        ax[pos].set_title('Batch {}, Cell {}'.format(batch, cell))
        plt.show()
        pos += 1
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-37-0937c790255b> in <module>
#       6         ax[pos].imshow(feature_dict.get('appearances')[batch][possibly_died.get(batch).get(cell)][cell])
#       7         ax[pos].set_title('Batch {}, Cell {}'.format(batch, cell))
# ----> 8         plt.show()
#       9         pos += 1
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/pyplot.py in show(*args, **kwargs)
#     351     """
#     352     _warn_if_gui_out_of_main_thread()
# --> 353     return _backend_mod.show(*args, **kwargs)
#     354
#     355
#
# /usr/local/lib/python3.6/dist-packages/ipykernel/pylab/backend_inline.py in show(close, block)
#      40             display(
#      41                 figure_manager.canvas.figure,
# ---> 42                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      43             )
# ...

# %%
for batch in range(num_batches):
    fig, ax = plt.subplots(1, max_batch_deaths)
    possibly_died_batch = possibly_died.get(batch).keys()
    pos = 0
    for cell in possibly_died_batch:
        ax[pos].imshow(feature_dict.get('appearances')[batch][possibly_died.get(batch).get(cell)][cell])
        ax[pos].set_title('Batch {}, Cell {}'.format(batch, cell))
        plt.show()
        pos += 1
